# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
train_data = "output/train/"
val_data = "output/val/"
test_data = "output/test/"


batch_size = 64
img_height = 150
img_width = 150

# %%
import splitfolders

splitfolders.ratio('training/', output="output", seed=1337, ratio=(.7, 0.2,0.1))

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255 )
                                 
                                 
train_generator = train_datagen.flow_from_directory(train_data,
                                                   target_size=(img_width, img_height),
                                                   batch_size=batch_size,
                                                   
                                                   shuffle=True)
# Out:
# Found 10144 images belonging to 3 classes.

# %%
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255 ,validation_split=0.2)
                                 
                                 
val_generator= val_datagen.flow_from_directory(val_data,
                                                   target_size=(img_width, img_height),
                                                   batch_size=batch_size,                                                 
                                                   
                                                   shuffle=True)
# Out:
# Found 2898 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : apple_fuji_L
# 1 : apple_fuji_M
# 2 : apple_fuji_S

# %%
num_classes = 3

model = Sequential([
  
  layers.Conv2D(64, (3,3), padding='valid', input_shape=(img_height,img_width,3),activation='relu'),
  layers.MaxPooling2D((2,2)),

  layers.Conv2D(32, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
  
  layers.Conv2D(64, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
 
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 256)               4735232
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 4,774,755
# Trainable params: 4,774,755
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_callback =model.fit(train_generator, epochs=10, validation_data=val_generator)
#callbacks=[reduce_lr]
# Out:
# Epoch 1/10
# 182/182 [==============================] - 306s 2s/step - loss: 0.5745 - accuracy: 0.7553 - val_loss: 0.3373 - val_accuracy: 0.8709
# Epoch 2/10
# 182/182 [==============================] - 304s 2s/step - loss: 0.3646 - accuracy: 0.8602 - val_loss: 0.2488 - val_accuracy: 0.9130
# Epoch 3/10
# 182/182 [==============================] - 302s 2s/step - loss: 0.3034 - accuracy: 0.8856 - val_loss: 0.1995 - val_accuracy: 0.9351
# Epoch 4/10
# 182/182 [==============================] - 304s 2s/step - loss: 0.2235 - accuracy: 0.9166 - val_loss: 0.1544 - val_accuracy: 0.9413
# Epoch 5/10
# 182/182 [==============================] - 302s 2s/step - loss: 0.1934 - accuracy: 0.9267 - val_loss: 0.2095 - val_accuracy: 0.9196
# Epoch 6/10
# 182/182 [==============================] - 300s 2s/step - loss: 0.1427 - accuracy: 0.9458 - val_loss: 0.1020 - val_accuracy: 0.9665
# Epoch 7/10
# 182/182 [==============================] - 303s 2s/step - loss: 0.1344 - accuracy: 0.9497 - val_loss: 0.1205 - val_accuracy: 0.9555
# Epoch 8/10
# 182/182 [==============================] - 305s 2s/step - loss: 0.1279 - accuracy: 0.9511 - val_loss: 0.0959 - val_accuracy: 0.9655
# Epoch 9/10
# 182/182 [==============================] - 300s 2s/step - loss: 0.1211 - accuracy: 0.9536 - val_loss: 0.1889 - val_accuracy: 0.9334
# Epoch 10/10
# 182/182 [==============================] - 296s 2s/step - loss: 0.1112 - accuracy: 0.9571 - val_loss: 0.1235 - val_accuracy: 0.9576

# %%
num_classes = 3

model2 = Sequential([
  
  layers.Conv2D(64, (3,3), padding='valid', input_shape=(img_height,img_width,3),activation='relu'),
  layers.MaxPooling2D((2,2)),

  layers.Conv2D(32, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
  
  layers.Conv2D(64, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
 
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation='softmax')
])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
model2.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_callback =model2.fit(train_generator, epochs=10, validation_data=val_generator,callbacks=[reduce_lr])
# Out:
# Epoch 1/10
# 182/182 [==============================] - 298s 2s/step - loss: 0.7093 - accuracy: 0.6815 - val_loss: 0.3837 - val_accuracy: 0.8644 - lr: 0.0010
# Epoch 2/10
# 182/182 [==============================] - 296s 2s/step - loss: 0.3711 - accuracy: 0.8574 - val_loss: 0.2147 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 3/10
# 182/182 [==============================] - 303s 2s/step - loss: 0.2704 - accuracy: 0.8990 - val_loss: 0.1733 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 4/10
# 182/182 [==============================] - 295s 2s/step - loss: 0.2166 - accuracy: 0.9176 - val_loss: 0.1360 - val_accuracy: 0.9551 - lr: 0.0010
# Epoch 5/10
# 182/182 [==============================] - 295s 2s/step - loss: 0.1769 - accuracy: 0.9317 - val_loss: 0.1142 - val_accuracy: 0.9589 - lr: 0.0010
# Epoch 6/10
# 182/182 [==============================] - 296s 2s/step - loss: 0.1661 - accuracy: 0.9395 - val_loss: 0.1475 - val_accuracy: 0.9462 - lr: 0.0010
# Epoch 7/10
# 182/182 [==============================] - 295s 2s/step - loss: 0.1283 - accuracy: 0.9507 - val_loss: 0.1029 - val_accuracy: 0.9614 - lr: 0.0010
# Epoch 8/10
# 182/182 [==============================] - 295s 2s/step - loss: 0.1140 - accuracy: 0.9604 - val_loss: 0.1585 - val_accuracy: 0.9431 - lr: 0.0010
# Epoch 9/10
# 182/182 [==============================] - 296s 2s/step - loss: 0.1063 - accuracy: 0.9602 - val_loss: 0.3715 - val_accuracy: 0.8823 - lr: 0.0010
# Epoch 10/10
# 182/182 [==============================] - 293s 2s/step - loss: 0.1047 - accuracy: 0.9630 - val_loss: 0.1670 - val_accuracy: 0.9482 - lr: 0.0010

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8836/2347784758.py in <module>
#      16
#      17 ax[2].set_title('Learning Rate vs. Epochs')
# ---> 18 ax[2].plot(learning_rate, 'o-', label='Learning Rate')
#      19 ax[2].set_xlabel('Epochs')
#      20 ax[2].set_ylabel('Loss')
#
# NameError: name 'learning_rate' is not defined

# %%
train_accuracy = history_callback.history['accuracy']
val_accuracy = history_callback.history['val_accuracy']

train_loss = history_callback.history['loss']
val_loss = history_callback.history['val_loss']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8836/2347784758.py in <module>
#      16
#      17 ax[2].set_title('Learning Rate vs. Epochs')
# ---> 18 ax[2].plot(learning_rate, 'o-', label='Learning Rate')
#      19 ax[2].set_xlabel('Epochs')
#      20 ax[2].set_ylabel('Loss')
#
# NameError: name 'learning_rate' is not defined

# %%
num_classes = 3

model3 = Sequential([
  
  layers.Conv2D(128, (3,3), padding='valid', input_shape=(img_height,img_width,3),activation='relu'),
  layers.MaxPooling2D((2,2)),

  layers.Conv2D(64, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
  
  layers.Conv2D(32, (3,3), padding='valid', activation='relu'),
  layers.MaxPooling2D((2,2)),
 
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 148, 148, 128)     3584
#
#  max_pooling2d_9 (MaxPooling  (None, 74, 74, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 72, 72, 64)        73792
#
#  max_pooling2d_10 (MaxPoolin  (None, 36, 36, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 34, 34, 32)        18464
#
#  max_pooling2d_11 (MaxPoolin  (None, 17, 17, 32)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 9248)              0
#
#  dense_6 (Dense)             (None, 256)               2367744
#
#  dense_7 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 2,464,355
# Trainable params: 2,464,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
model3.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_callback =model3.fit(train_generator, epochs=10, validation_data=val_generator,callbacks=[reduce_lr])
# Out:
# Epoch 1/10
# 159/159 [==============================] - 252s 2s/step - loss: 0.7628 - accuracy: 0.6431 - val_loss: 0.6206 - val_accuracy: 0.7202 - lr: 0.0010
# Epoch 2/10
# 159/159 [==============================] - 249s 2s/step - loss: 0.4299 - accuracy: 0.8299 - val_loss: 0.3704 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 3/10
# 159/159 [==============================] - 251s 2s/step - loss: 0.3086 - accuracy: 0.8864 - val_loss: 0.2909 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 4/10
# 159/159 [==============================] - 250s 2s/step - loss: 0.2575 - accuracy: 0.9060 - val_loss: 0.2461 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 5/10
# 159/159 [==============================] - 250s 2s/step - loss: 0.2336 - accuracy: 0.9141 - val_loss: 0.2542 - val_accuracy: 0.8996 - lr: 0.0010
# Epoch 6/10
# 159/159 [==============================] - 255s 2s/step - loss: 0.1758 - accuracy: 0.9354 - val_loss: 0.2143 - val_accuracy: 0.9199 - lr: 0.0010
# Epoch 7/10
# 159/159 [==============================] - 253s 2s/step - loss: 0.1568 - accuracy: 0.9403 - val_loss: 0.3133 - val_accuracy: 0.8827 - lr: 0.0010
# Epoch 8/10
# 159/159 [==============================] - 252s 2s/step - loss: 0.1203 - accuracy: 0.9556 - val_loss: 0.2224 - val_accuracy: 0.9161 - lr: 0.0010
# Epoch 9/10
# 159/159 [==============================] - 252s 2s/step - loss: 0.1111 - accuracy: 0.9579 - val_loss: 0.1849 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 10/10
# 159/159 [==============================] - 252s 2s/step - loss: 0.0856 - accuracy: 0.9675 - val_loss: 0.1319 - val_accuracy: 0.9534 - lr: 0.0010

# %%
train_accuracy = history_callback.history['accuracy']
val_accuracy = history_callback.history['val_accuracy']

train_loss = history_callback.history['loss']
val_loss = history_callback.history['val_loss']
learning_rate = history_callback.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
train_accuracy = history_callback.history['accuracy']
val_accuracy = history_callback.history['val_accuracy']

train_loss = history_callback.history['loss']
val_loss = history_callback.history['val_loss']
learning_rate = history_callback.history['lr']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 train_accuracy = history_callback.history['accuracy']
#       2 val_accuracy = history_callback.history['val_accuracy']
#       4 train_loss = history_callback.history['loss']
#
# NameError: name 'history_callback' is not defined

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_data,
                                                 batch_size=batch_size,
                                                 target_size = (img_height, img_width),
                                                 class_mode='categorical')
# Out:
# Found 1452 images belonging to 3 classes.

# %%
predictions = model3.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset result", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = model3.evaluate(test_generator, batch_size=batch_size)
# Out:
# 23/23 [==============================] - 33s 1s/step - loss: 0.1412 - accuracy: 0.9470

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.14120039343833923
# Test Accuracy: 0.9469696879386902

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
import cv2

fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(16, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_data, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()

# %%
# 아까 사용한 model3 컨버터 하기
converter = tf.lite.TFLiteConverter.from_keras_model(model3)
tflite_float_model = converter.convert()

# 양자화 확인을 위한 kb.
float_model_size = len(tflite_float_model) / 1024
print('Float model size = %dKBs.' % float_model_size)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\82103\AppData\Local\Temp\tmpsgvdrjc7\assets
# INFO:tensorflow:Assets written to: C:\Users\82103\AppData\Local\Temp\tmpsgvdrjc7\assets
# Float model size = 9629KBs.

# %%
# Default값은 동적 범위 양자화(8bit)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

# 양자화 확인 4배 줄면 됨
quantized_model_size = len(tflite_quantized_model) / 1024
print('Quantized model size = %dKBs,' % quantized_model_size)
print('which is about %d%% of the float model size.'\
      % (quantized_model_size * 100 / float_model_size))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\82103\AppData\Local\Temp\tmp047gzavp\assets
# INFO:tensorflow:Assets written to: C:\Users\82103\AppData\Local\Temp\tmp047gzavp\assets
# Quantized model size = 2418KBs,
# which is about 25% of the float model size.

# %%
# 저장
f = open('model2.tflite', "wb")
f.write(tflite_quantized_model)
f.close()

# %%
interpreter = tf.lite.Interpreter(model_path="./ddd/apple_not_qua.tflite")

for item in interpreter.get_tensor_details():
    for key in item.keys():
        print("%s : %s" % (key, item[key]))
    print("")
# Out:
# name : serving_default_conv2d_input:0
# index : 0
# shape : [  1 150 150   3]
# shape_signature : [ -1 150 150   3]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_2/Conv2D
# index : 1
# shape : [32]
# shape_signature : [32]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_1/Conv2D
# index : 2
# shape : [64]
# shape_signature : [64]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d/Conv2D
# index : 3
# shape : [128]
# shape_signature : [128]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/flatten/Const
# index : 4
# shape : [2]
# shape_signature : [2]
# dtype : <class 'numpy.int32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/dense/MatMul
# index : 5
# shape : [ 256 9248]
# shape_signature : [ 256 9248]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/dense_1/MatMul
# index : 6
# shape : [  3 256]
# shape_signature : [  3 256]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d/Conv2D1
# index : 7
# shape : [128   3   3   3]
# shape_signature : [128   3   3   3]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_1/Conv2D1
# index : 8
# shape : [ 64   3   3 128]
# shape_signature : [ 64   3   3 128]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_2/Conv2D1
# index : 9
# shape : [32  3  3 64]
# shape_signature : [32  3  3 64]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d/Relu;sequential/conv2d/BiasAdd;sequential/conv2d/Conv2D
# index : 10
# shape : [  1 148 148 128]
# shape_signature : [ -1 148 148 128]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/max_pooling2d/MaxPool
# index : 11
# shape : [  1  74  74 128]
# shape_signature : [ -1  74  74 128]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_1/Relu;sequential/conv2d_1/BiasAdd;sequential/conv2d_1/Conv2D
# index : 12
# shape : [ 1 72 72 64]
# shape_signature : [-1 72 72 64]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/max_pooling2d_1/MaxPool
# index : 13
# shape : [ 1 36 36 64]
# shape_signature : [-1 36 36 64]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/conv2d_2/Relu;sequential/conv2d_2/BiasAdd;sequential/conv2d_2/Conv2D
# index : 14
# shape : [ 1 34 34 32]
# shape_signature : [-1 34 34 32]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/max_pooling2d_2/MaxPool
# index : 15
# shape : [ 1 17 17 32]
# shape_signature : [-1 17 17 32]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/flatten/Reshape
# index : 16
# shape : [   1 9248]
# shape_signature : [  -1 9248]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/dense/MatMul;sequential/dense/Relu;sequential/dense/BiasAdd
# index : 17
# shape : [  1 256]
# shape_signature : [ -1 256]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : sequential/dense_1/MatMul;sequential/dense_1/BiasAdd
# index : 18
# shape : [1 3]
# shape_signature : [-1  3]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
#
# name : StatefulPartitionedCall:0
# index : 19
# shape : [1 3]
# shape_signature : [-1  3]
# dtype : <class 'numpy.float32'>
# quantization : (0.0, 0)
# quantization_parameters : {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}
# sparsity_parameters : {}
